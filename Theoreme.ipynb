# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from math import exp, sqrt, pi

# %%
domaine = range (-100, 100)
mu = 0
sigma = 20
f = lambda x : 1/(sqrt(2*pi*pow(sigma,2))) * exp(-pow((x-mu),2)/(2*pow(sigma,2)))
y= [f(x) for x in domaine]

plot=plt.plot(domaine,y)

# %%
vecteur_aleatoire = np.random.rand(30)

# %%
plt.scatter(range(30), vecteur_aleatoire)

# %%
plt.scatter(range(30), vecteur_aleatoire)

# %%
matrice_aleatoire=np.random.rand(3,5)

# %%
matrice_aleatoire
# Out:
# array([[0.5669619 , 0.47492882, 0.16729342, 0.21077726, 0.86212721],
#        [0.64991906, 0.58211717, 0.78318914, 0.26463674, 0.65859357],
#        [0.90127405, 0.08509271, 0.27890542, 0.71178547, 0.24341794]])

# %%
matrice = np.random.rand(100,200)

# %%
np.sum(matrice)
# Out:
# 9919.103966215425

# %%
somme = np.sum(matrice, 0)

# %%
somme.shape
# Out:
# (200,)

# %%
plt.scatter(range(200),somme)

# %%
plt.hist(somme)
# Out:
# (array([ 4., 12., 15., 25., 34., 40., 31., 26., 11.,  2.]),
#  array([42.09952259, 43.56818751, 45.03685243, 46.50551735, 47.97418226,
#         49.44284718, 50.9115121 , 52.38017702, 53.84884194, 55.31750686,
#         56.78617177]),
#  <a list of 10 Patch objects>)

# %%
matrice = np.random.rand(1000,10000)

# %%
somme = np.sum(matrice,0)

# %%
somme.shape
# Out:
# (10000,)

# %%
test =plt.hist(somme, bins=100)
